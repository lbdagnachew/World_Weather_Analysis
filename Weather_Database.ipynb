# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Get the nearest city using citipy
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Perfom API call using OpenWeatherMap

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If error, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto colombia
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | aksu
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | leningradskiy
# Processing Record 9 of Set 1 | hukuntsi
# Processing Record 10 of Set 1 | laguna
# Processing Record 11 of Set 1 | aanekoski
# Processing Record 12 of Set 1 | kavieng
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | manono
# Processing Record 17 of Set 1 | silopi
# Processing Record 18 of Set 1 | vyara
# Processing Record 19 of Set 1 | pevek
# Processing Record 20 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | hamilton
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | juneau
# Processing Record 28 of Set 1 | nalut
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | yar-sale
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | nabire
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | dunedin
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 38 of Set 1 | tsaratanana
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | chimoio
# Processing Record 43 of Set 1 | clyde river
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | luanda
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | gamba
# Processing Record 48 of Set 1 | umm kaddadah
# Processing Record 49 of Set 1 | prince rupert
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | eyl
# Processing Record 4 of Set 2 | san rafael del sur
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | nanortalik
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | kampot
# Processing Record 10 of Set 2 | bonoua
# Processing Record 11 of Set 2 | korla
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | hede
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | half moon bay
# Processing Record 17 of Set 2 | envira
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | faanui
# Processing Record 21 of Set 2 | buta
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | quatre cocos
# Processing Record 25 of Set 2 | te anau
# Processing Record 26 of Set 2 | nuuk
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | hidalgo
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | kutum
# Processing Record 31 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | yarensk
# Processing Record 34 of Set 2 | kawalu
# Processing Record 35 of Set 2 | maues
# Processing Record 36 of Set 2 | charters towers
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | dickinson
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | nizhniy tsasuchey
# Processing Record 42 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | pocone
# Processing Record 48 of Set 2 | nizhnevartovsk
# Processing Record 49 of Set 2 | norrtalje
# Processing Record 50 of Set 2 | parabel
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | itoman
# Processing Record 4 of Set 3 | antofagasta
# Processing Record 5 of Set 3 | severo-yeniseyskiy
# Processing Record 6 of Set 3 | lugovoy
# Processing Record 7 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | karlovac
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | ternate
# Processing Record 14 of Set 3 | acarigua
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | gilgit
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | namatanai
# Processing Record 19 of Set 3 | tateyama
# Processing Record 20 of Set 3 | bundaberg
# Processing Record 21 of Set 3 | gboko
# Processing Record 22 of Set 3 | melfi
# Processing Record 23 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | nagato
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | jimo
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | hangu
# Processing Record 30 of Set 3 | pontes e lacerda
# Processing Record 31 of Set 3 | impfondo
# Processing Record 32 of Set 3 | hovd
# Processing Record 33 of Set 3 | oum hadjer
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | dharchula
# Processing Record 36 of Set 3 | boende
# Processing Record 37 of Set 3 | kalabo
# Processing Record 38 of Set 3 | broken hill
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | portland
# Processing Record 42 of Set 3 | assiniboia
# Processing Record 43 of Set 3 | ponta do sol
# Processing Record 44 of Set 3 | taoudenni
# Processing Record 45 of Set 3 | mar del plata
# Processing Record 46 of Set 3 | kardamaina
# Processing Record 47 of Set 3 | trinidad
# Processing Record 48 of Set 3 | meulaboh
# Processing Record 49 of Set 3 | vlagtwedde
# Processing Record 50 of Set 3 | zlobin
# Processing Record 1 of Set 4 | kingussie
# Processing Record 2 of Set 4 | chagoda
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | ancud
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | jamame
# Processing Record 7 of Set 4 | bodden town
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | upernavik
# Processing Record 10 of Set 4 | barra do garcas
# Processing Record 11 of Set 4 | lagoa
# Processing Record 12 of Set 4 | tual
# Processing Record 13 of Set 4 | necochea
# Processing Record 14 of Set 4 | adrar
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | dubbo
# Processing Record 17 of Set 4 | tecpan
# Processing Record 18 of Set 4 | hanyang
# Processing Record 19 of Set 4 | kruisfontein
# Processing Record 20 of Set 4 | gunjur
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | menongue
# Processing Record 23 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 4 | santarem
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | malartic
# Processing Record 27 of Set 4 | kiama
# Processing Record 28 of Set 4 | savinka
# Processing Record 29 of Set 4 | hollins
# Processing Record 30 of Set 4 | nago
# Processing Record 31 of Set 4 | chengde
# Processing Record 32 of Set 4 | elizabeth city
# Processing Record 33 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 4 | aksarka
# Processing Record 35 of Set 4 | padre paraiso
# Processing Record 36 of Set 4 | filadelfia
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | mitsamiouli
# Processing Record 39 of Set 4 | sumenep
# Processing Record 40 of Set 4 | hermanus
# Processing Record 41 of Set 4 | comodoro rivadavia
# Processing Record 42 of Set 4 | quang ngai
# Processing Record 43 of Set 4 | vardo
# Processing Record 44 of Set 4 | kavaratti
# Processing Record 45 of Set 4 | coihaique
# Processing Record 46 of Set 4 | abha
# Processing Record 47 of Set 4 | ponta pora
# Processing Record 48 of Set 4 | anadyr
# Processing Record 49 of Set 4 | junction city
# Processing Record 50 of Set 4 | awjilah
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | creel
# Processing Record 3 of Set 5 | awbari
# Processing Record 4 of Set 5 | wanning
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | dombarovskiy
# Processing Record 7 of Set 5 | agua branca
# Processing Record 8 of Set 5 | santa isabel do rio negro
# Processing Record 9 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 5 | tulum
# Processing Record 15 of Set 5 | alexandria
# Processing Record 16 of Set 5 | fortuna foothills
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | milkovo
# Processing Record 19 of Set 5 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | mount gambier
# Processing Record 22 of Set 5 | saint-joseph
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | pedasi
# Processing Record 25 of Set 5 | hokitika
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 5 | fortuna
# Processing Record 31 of Set 5 | preobrazheniye
# Processing Record 32 of Set 5 | shabo
# Processing Record 33 of Set 5 | safonovo
# Processing Record 34 of Set 5 | saint-felicien
# Processing Record 35 of Set 5 | indi
# Processing Record 36 of Set 5 | kralendijk
# Processing Record 37 of Set 5 | tashtagol
# Processing Record 38 of Set 5 | kollam
# Processing Record 39 of Set 5 | tasiilaq
# Processing Record 40 of Set 5 | ulladulla
# Processing Record 41 of Set 5 | margate
# Processing Record 42 of Set 5 | petatlan
# Processing Record 43 of Set 5 | hirara
# Processing Record 44 of Set 5 | puerto madryn
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | calca
# Processing Record 47 of Set 5 | vila
# Processing Record 48 of Set 5 | wiefelstede
# Processing Record 49 of Set 5 | arenapolis
# Processing Record 50 of Set 5 | kailua
# Processing Record 1 of Set 6 | diego de almagro
# Processing Record 2 of Set 6 | ambon
# Processing Record 3 of Set 6 | keti bandar
# Processing Record 4 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | havre-saint-pierre
# Processing Record 7 of Set 6 | bhag
# Processing Record 8 of Set 6 | gravdal
# Processing Record 9 of Set 6 | port macquarie
# Processing Record 10 of Set 6 | san patricio
# Processing Record 11 of Set 6 | hlotse
# Processing Record 12 of Set 6 | maceio
# Processing Record 13 of Set 6 | san vicente
# Processing Record 14 of Set 6 | semnan
# Processing Record 15 of Set 6 | marsa matruh
# Processing Record 16 of Set 6 | fort nelson
# Processing Record 17 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 6 | tautira
# Processing Record 19 of Set 6 | rochester
# Processing Record 20 of Set 6 | airai
# Processing Record 21 of Set 6 | ballina
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | beatrice
# Processing Record 24 of Set 6 | krasnoselkup
# Processing Record 25 of Set 6 | pangody
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | dori
# Processing Record 29 of Set 6 | tanga
# Processing Record 30 of Set 6 | aktau
# Processing Record 31 of Set 6 | ostrovnoy
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | caravelas
# Processing Record 34 of Set 6 | roma
# Processing Record 35 of Set 6 | shimoda
# Processing Record 36 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 6 | chara
# Processing Record 38 of Set 6 | shirokiy
# Processing Record 39 of Set 6 | ribeira grande
# Processing Record 40 of Set 6 | touros
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | maku
# Processing Record 43 of Set 6 | george town
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | kununurra
# Processing Record 46 of Set 6 | calderitas
# Processing Record 47 of Set 6 | moron
# Processing Record 48 of Set 6 | mastic beach
# Processing Record 49 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 50 of Set 6 | sisimiut
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | huarmey
# Processing Record 3 of Set 7 | santa maria da boa vista
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | pangnirtung
# Processing Record 6 of Set 7 | hammerfest
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | lahij
# Processing Record 9 of Set 7 | eureka
# Processing Record 10 of Set 7 | hakui
# Processing Record 11 of Set 7 | college
# Processing Record 12 of Set 7 | staryy nadym
# Processing Record 13 of Set 7 | duluth
# Processing Record 14 of Set 7 | borba
# Processing Record 15 of Set 7 | sychevka
# Processing Record 16 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 7 | pasni
# Processing Record 18 of Set 7 | kieta
# Processing Record 19 of Set 7 | werda
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | saint-pierre
# Processing Record 22 of Set 7 | sola
# Processing Record 23 of Set 7 | sao jose da coroa grande
# Processing Record 24 of Set 7 | fomboni
# Processing Record 25 of Set 7 | vreed en hoop
# City not found. Skipping...
# Processing Record 26 of Set 7 | chifeng
# Processing Record 27 of Set 7 | singkang
# Processing Record 28 of Set 7 | karonga
# Processing Record 29 of Set 7 | harwich
# Processing Record 30 of Set 7 | saskylakh
# Processing Record 31 of Set 7 | kijang
# Processing Record 32 of Set 7 | kasama
# Processing Record 33 of Set 7 | moosburg
# Processing Record 34 of Set 7 | salalah
# Processing Record 35 of Set 7 | posse
# Processing Record 36 of Set 7 | morant bay
# Processing Record 37 of Set 7 | grand forks
# Processing Record 38 of Set 7 | saint george
# Processing Record 39 of Set 7 | colares
# Processing Record 40 of Set 7 | arraial do cabo
# Processing Record 41 of Set 7 | bykovo
# Processing Record 42 of Set 7 | pasighat
# Processing Record 43 of Set 7 | maxixe
# Processing Record 44 of Set 7 | senanga
# Processing Record 45 of Set 7 | gari
# Processing Record 46 of Set 7 | ilulissat
# Processing Record 47 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 7 | bilibino
# Processing Record 49 of Set 7 | foz
# Processing Record 50 of Set 7 | jabinyanah
# Processing Record 1 of Set 8 | alice springs
# Processing Record 2 of Set 8 | roald
# Processing Record 3 of Set 8 | berlevag
# Processing Record 4 of Set 8 | kaeo
# Processing Record 5 of Set 8 | chapada dos guimaraes
# Processing Record 6 of Set 8 | ca mau
# Processing Record 7 of Set 8 | la ronge
# Processing Record 8 of Set 8 | leshukonskoye
# Processing Record 9 of Set 8 | san-pedro
# Processing Record 10 of Set 8 | tadine
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | cabo san lucas
# Processing Record 13 of Set 8 | victoria
# Processing Record 14 of Set 8 | taltal
# Processing Record 15 of Set 8 | sangar
# Processing Record 16 of Set 8 | argelia
# Processing Record 17 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 8 | cayeli
# Processing Record 19 of Set 8 | erzurum
# Processing Record 20 of Set 8 | pahrump
# Processing Record 21 of Set 8 | natal
# Processing Record 22 of Set 8 | badou
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | nova olimpia
# Processing Record 25 of Set 8 | kihei
# Processing Record 26 of Set 8 | tabou
# Processing Record 27 of Set 8 | ixtapa
# Processing Record 28 of Set 8 | jiwani
# Processing Record 29 of Set 8 | ridgecrest
# Processing Record 30 of Set 8 | pathein
# Processing Record 31 of Set 8 | camapua
# Processing Record 32 of Set 8 | braganca
# Processing Record 33 of Set 8 | nkowakowa
# Processing Record 34 of Set 8 | conceicao do araguaia
# Processing Record 35 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | kouvaras
# Processing Record 39 of Set 8 | vila do maio
# Processing Record 40 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 8 | south river
# Processing Record 42 of Set 8 | pyay
# Processing Record 43 of Set 8 | urumqi
# Processing Record 44 of Set 8 | tilichiki
# Processing Record 45 of Set 8 | oistins
# Processing Record 46 of Set 8 | hambantota
# Processing Record 47 of Set 8 | teguldet
# Processing Record 48 of Set 8 | sao joao da barra
# Processing Record 49 of Set 8 | saint-augustin
# Processing Record 50 of Set 8 | chapais
# Processing Record 1 of Set 9 | vaitape
# Processing Record 2 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 9 | jumla
# Processing Record 4 of Set 9 | iqaluit
# Processing Record 5 of Set 9 | luau
# Processing Record 6 of Set 9 | linxia
# Processing Record 7 of Set 9 | san quintin
# Processing Record 8 of Set 9 | presidencia roque saenz pena
# Processing Record 9 of Set 9 | jacareacanga
# Processing Record 10 of Set 9 | beringovskiy
# Processing Record 11 of Set 9 | itarema
# Processing Record 12 of Set 9 | tsiroanomandidy
# Processing Record 13 of Set 9 | niquero
# Processing Record 14 of Set 9 | waipawa
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | norman wells
# Processing Record 17 of Set 9 | constitucion
# Processing Record 18 of Set 9 | candolim
# Processing Record 19 of Set 9 | plettenberg bay
# Processing Record 20 of Set 9 | suntar
# Processing Record 21 of Set 9 | olafsvik
# Processing Record 22 of Set 9 | fairfax
# Processing Record 23 of Set 9 | magadan
# Processing Record 24 of Set 9 | anloga
# Processing Record 25 of Set 9 | matagami
# Processing Record 26 of Set 9 | baley
# Processing Record 27 of Set 9 | saint-paul
# Processing Record 28 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 29 of Set 9 | burnie
# Processing Record 30 of Set 9 | dakar
# Processing Record 31 of Set 9 | estelle
# Processing Record 32 of Set 9 | volchikha
# Processing Record 33 of Set 9 | byron bay
# Processing Record 34 of Set 9 | kodiak
# Processing Record 35 of Set 9 | verkhnevilyuysk
# Processing Record 36 of Set 9 | kota kinabalu
# Processing Record 37 of Set 9 | tikapur
# Processing Record 38 of Set 9 | umea
# Processing Record 39 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 9 | lorengau
# Processing Record 41 of Set 9 | stefanestii de jos
# Processing Record 42 of Set 9 | tomiya
# Processing Record 43 of Set 9 | mirpur bathoro
# City not found. Skipping...
# Processing Record 44 of Set 9 | muisne
# Processing Record 45 of Set 9 | carnarvon
# Processing Record 46 of Set 9 | merauke
# Processing Record 47 of Set 9 | bath
# Processing Record 48 of Set 9 | ola
# Processing Record 49 of Set 9 | asau
# Processing Record 50 of Set 9 | mugla
# Processing Record 1 of Set 10 | big spring
# Processing Record 2 of Set 10 | gat
# Processing Record 3 of Set 10 | rantepao
# Processing Record 4 of Set 10 | ambilobe
# Processing Record 5 of Set 10 | cambrai
# Processing Record 6 of Set 10 | taiyuan
# Processing Record 7 of Set 10 | akot
# Processing Record 8 of Set 10 | cascais
# Processing Record 9 of Set 10 | finschhafen
# Processing Record 10 of Set 10 | higuey
# City not found. Skipping...
# Processing Record 11 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 10 | haines junction
# Processing Record 13 of Set 10 | ahipara
# Processing Record 14 of Set 10 | loviisa
# Processing Record 15 of Set 10 | bodoco
# City not found. Skipping...
# Processing Record 16 of Set 10 | husavik
# Processing Record 17 of Set 10 | carutapera
# Processing Record 18 of Set 10 | santiago
# Processing Record 19 of Set 10 | svobodnyy
# Processing Record 20 of Set 10 | puri
# Processing Record 21 of Set 10 | orange cove
# Processing Record 22 of Set 10 | waterloo
# Processing Record 23 of Set 10 | voila
# Processing Record 24 of Set 10 | dargaville
# Processing Record 25 of Set 10 | aklavik
# Processing Record 26 of Set 10 | san cristobal
# Processing Record 27 of Set 10 | shu
# Processing Record 28 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 10 | baijiantan
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | santa cruz
# Processing Record 32 of Set 10 | axim
# Processing Record 33 of Set 10 | broome
# Processing Record 34 of Set 10 | plastun
# Processing Record 35 of Set 10 | mecca
# Processing Record 36 of Set 10 | baglung
# Processing Record 37 of Set 10 | bom jesus da lapa
# Processing Record 38 of Set 10 | palora
# Processing Record 39 of Set 10 | tanout
# Processing Record 40 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 10 | kudat
# Processing Record 42 of Set 10 | trindade
# Processing Record 43 of Set 10 | padang
# Processing Record 44 of Set 10 | jasper
# Processing Record 45 of Set 10 | terrace
# Processing Record 46 of Set 10 | maragogi
# Processing Record 47 of Set 10 | olinda
# Processing Record 48 of Set 10 | mehran
# Processing Record 49 of Set 10 | jining
# Processing Record 50 of Set 10 | turukhansk
# Processing Record 1 of Set 11 | groningen
# Processing Record 2 of Set 11 | tigil
# Processing Record 3 of Set 11 | behshahr
# Processing Record 4 of Set 11 | manta
# Processing Record 5 of Set 11 | aguimes
# Processing Record 6 of Set 11 | west wendover
# Processing Record 7 of Set 11 | tolaga bay
# Processing Record 8 of Set 11 | lerici
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | shingu
# Processing Record 11 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 11 | westport
# Processing Record 13 of Set 11 | makubetsu
# Processing Record 14 of Set 11 | ovalle
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | los llanos de aridane
# Processing Record 17 of Set 11 | netanya
# Processing Record 18 of Set 11 | maroantsetra
# Processing Record 19 of Set 11 | mandera
# Processing Record 20 of Set 11 | gemena
# Processing Record 21 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 11 | riohacha
# Processing Record 23 of Set 11 | nemuro
# Processing Record 24 of Set 11 | sumbe
# Processing Record 25 of Set 11 | makakilo city
# Processing Record 26 of Set 11 | fort-shevchenko
# Processing Record 27 of Set 11 | beaumont
# Processing Record 28 of Set 11 | manado
# Processing Record 29 of Set 11 | muli
# Processing Record 30 of Set 11 | myanaung
# Processing Record 31 of Set 11 | hay river
# Processing Record 32 of Set 11 | kangaatsiaq
# Processing Record 33 of Set 11 | alamosa
# Processing Record 34 of Set 11 | kamenka
# Processing Record 35 of Set 11 | kemin
# Processing Record 36 of Set 11 | el alto
# Processing Record 37 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 11 | vostok
# Processing Record 39 of Set 11 | turbat
# Processing Record 40 of Set 11 | alyangula
# Processing Record 41 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 11 | kysyl-syr
# Processing Record 43 of Set 11 | saint-georges
# Processing Record 44 of Set 11 | taguatinga
# Processing Record 45 of Set 11 | sao miguel do araguaia
# Processing Record 46 of Set 11 | vila velha
# Processing Record 47 of Set 11 | cornwall
# Processing Record 48 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 11 | kushima
# Processing Record 50 of Set 11 | kushiro
# Processing Record 1 of Set 12 | kisangani
# Processing Record 2 of Set 12 | poum
# Processing Record 3 of Set 12 | the valley
# Processing Record 4 of Set 12 | boffa
# Processing Record 5 of Set 12 | angatuba
# Processing Record 6 of Set 12 | adeje
# Processing Record 7 of Set 12 | dumka
# Processing Record 8 of Set 12 | afantou
# Processing Record 9 of Set 12 | zvishavane
# Processing Record 10 of Set 12 | manay
# Processing Record 11 of Set 12 | atasu
# Processing Record 12 of Set 12 | neuquen
# Processing Record 13 of Set 12 | caceres
# Processing Record 14 of Set 12 | valparaiso
# Processing Record 15 of Set 12 | mbandaka
# Processing Record 16 of Set 12 | kalivai poliyirou
# City not found. Skipping...
# Processing Record 17 of Set 12 | tilbury
# Processing Record 18 of Set 12 | acapulco
# Processing Record 19 of Set 12 | annau
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | bubaque
# Processing Record 22 of Set 12 | micula
# Processing Record 23 of Set 12 | longmont
# Processing Record 24 of Set 12 | paamiut
# Processing Record 25 of Set 12 | port blair
# Processing Record 26 of Set 12 | gazanjyk
# Processing Record 27 of Set 12 | salihorsk
# Processing Record 28 of Set 12 | tiznit
# Processing Record 29 of Set 12 | doha
# Processing Record 30 of Set 12 | codrington
# Processing Record 31 of Set 12 | akyab
# Processing Record 32 of Set 12 | kharovsk
# Processing Record 33 of Set 12 | totness
# Processing Record 34 of Set 12 | bonnyville
# Processing Record 35 of Set 12 | rocha
# Processing Record 36 of Set 12 | gorele
# Processing Record 37 of Set 12 | svetlaya
# Processing Record 38 of Set 12 | lakhdenpokhya
# Processing Record 39 of Set 12 | nome
# Processing Record 40 of Set 12 | vao
# Processing Record 41 of Set 12 | henties bay
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 12 | high wycombe
# Processing Record 44 of Set 12 | balabac
# Processing Record 45 of Set 12 | lasa
# Processing Record 46 of Set 12 | tamuin
# Processing Record 47 of Set 12 | ponta delgada
# Processing Record 48 of Set 12 | port hardy
# Processing Record 49 of Set 12 | sumter
# Processing Record 50 of Set 12 | manbij
# Processing Record 1 of Set 13 | shenkursk
# Processing Record 2 of Set 13 | linjiang
# Processing Record 3 of Set 13 | grand bank
# Processing Record 4 of Set 13 | melo
# Processing Record 5 of Set 13 | mizdah
# Processing Record 6 of Set 13 | kirakira
# Processing Record 7 of Set 13 | nhulunbuy
# Processing Record 8 of Set 13 | clyde
# Processing Record 9 of Set 13 | rock springs
# Processing Record 10 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 13 | znamenka
# Processing Record 12 of Set 13 | vanimo
# Processing Record 13 of Set 13 | rawson
# Processing Record 14 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 13 | barabai
# Processing Record 16 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 17 of Set 13 | san andres
# Processing Record 18 of Set 13 | camacha
# Processing Record 19 of Set 13 | nouakchott
# Processing Record 20 of Set 13 | madhugiri
# Processing Record 21 of Set 13 | george
# Processing Record 22 of Set 13 | chivasso
# Processing Record 23 of Set 13 | devonport
# Processing Record 24 of Set 13 | japura
# Processing Record 25 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 13 | rauma
# Processing Record 27 of Set 13 | poltavka
# Processing Record 28 of Set 13 | edson
# Processing Record 29 of Set 13 | phan thiet
# Processing Record 30 of Set 13 | porto velho
# Processing Record 31 of Set 13 | riviere-au-renard
# Processing Record 32 of Set 13 | choucheng
# City not found. Skipping...
# Processing Record 33 of Set 13 | abu samrah
# Processing Record 34 of Set 13 | seymchan
# Processing Record 35 of Set 13 | vomp
# Processing Record 36 of Set 13 | birin
# Processing Record 37 of Set 13 | ahuimanu
# Processing Record 38 of Set 13 | goderich
# Processing Record 39 of Set 13 | havoysund
# Processing Record 40 of Set 13 | poplar bluff
# Processing Record 41 of Set 13 | bonthe
# Processing Record 42 of Set 13 | chumikan
# Processing Record 43 of Set 13 | hami
# Processing Record 44 of Set 13 | santiago del estero
# Processing Record 45 of Set 13 | fairbanks
# Processing Record 46 of Set 13 | corner brook
# Processing Record 47 of Set 13 | uray
# Processing Record 48 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 49 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 13 | kulhudhuffushi
# Processing Record 1 of Set 14 | longjiang
# Processing Record 2 of Set 14 | ventanas
# Processing Record 3 of Set 14 | shellbrook
# Processing Record 4 of Set 14 | marsh harbour
# Processing Record 5 of Set 14 | kemijarvi
# Processing Record 6 of Set 14 | fez
# Processing Record 7 of Set 14 | kamina
# Processing Record 8 of Set 14 | chulman
# Processing Record 9 of Set 14 | izhma
# Processing Record 10 of Set 14 | burns lake
# Processing Record 11 of Set 14 | oranjestad
# Processing Record 12 of Set 14 | polur
# Processing Record 13 of Set 14 | greenwood
# Processing Record 14 of Set 14 | nantucket
# Processing Record 15 of Set 14 | baker city
# Processing Record 16 of Set 14 | salta
# Processing Record 17 of Set 14 | mahon
# Processing Record 18 of Set 14 | zverinogolovskoye
# Processing Record 19 of Set 14 | varhaug
# Processing Record 20 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 14 | olenino
# Processing Record 22 of Set 14 | moree
# Processing Record 23 of Set 14 | coahuayana
# Processing Record 24 of Set 14 | amahai
# Processing Record 25 of Set 14 | temba
# Processing Record 26 of Set 14 | hofn
# Processing Record 27 of Set 14 | kalmunai
# Processing Record 28 of Set 14 | yulara
# Processing Record 29 of Set 14 | inongo
# Processing Record 30 of Set 14 | tura
# Processing Record 31 of Set 14 | bilma
# Processing Record 32 of Set 14 | kupang
# Processing Record 33 of Set 14 | guaruja
# Processing Record 34 of Set 14 | tombouctou
# Processing Record 35 of Set 14 | mayakonda
# Processing Record 36 of Set 14 | baykit
# Processing Record 37 of Set 14 | mujiayingzi
# Processing Record 38 of Set 14 | nouadhibou
# Processing Record 39 of Set 14 | north bend
# Processing Record 40 of Set 14 | lima
# Processing Record 41 of Set 14 | saint anthony
# Processing Record 42 of Set 14 | pundaguitan
# Processing Record 43 of Set 14 | katastarion
# Processing Record 44 of Set 14 | caucaia
# Processing Record 45 of Set 14 | cao bang
# Processing Record 46 of Set 14 | wanaka
# Processing Record 47 of Set 14 | la peca
# Processing Record 48 of Set 14 | virginia beach
# Processing Record 49 of Set 14 | redondo
# Processing Record 50 of Set 14 | zaykovo
# Processing Record 1 of Set 15 | humaita
# Processing Record 2 of Set 15 | tsybuliv
# Processing Record 3 of Set 15 | yuxia
# Processing Record 4 of Set 15 | huainan
# Processing Record 5 of Set 15 | vestmannaeyjar
# Processing Record 6 of Set 15 | abrau-dyurso
# Processing Record 7 of Set 15 | atar
# Processing Record 8 of Set 15 | nokaneng
# Processing Record 9 of Set 15 | mumford
# Processing Record 10 of Set 15 | novaya zaimka
# Processing Record 11 of Set 15 | dawei
# Processing Record 12 of Set 15 | livingston
# Processing Record 13 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 15 | novikovo
# Processing Record 15 of Set 15 | maraa
# Processing Record 16 of Set 15 | grazhdanskoye pervoye
# City not found. Skipping...
# Processing Record 17 of Set 15 | bonavista
# Processing Record 18 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 15 | altay
# Processing Record 20 of Set 15 | mosquera
# Processing Record 21 of Set 15 | lazaro cardenas
# Processing Record 22 of Set 15 | gambela
# Processing Record 23 of Set 15 | capinopolis
# Processing Record 24 of Set 15 | karlstad
# Processing Record 25 of Set 15 | bandarbeyla
# Processing Record 26 of Set 15 | kodinsk
# Processing Record 27 of Set 15 | ormara
# Processing Record 28 of Set 15 | zeya
# Processing Record 29 of Set 15 | faya
# Processing Record 30 of Set 15 | mersing
# Processing Record 31 of Set 15 | isla vista
# Processing Record 32 of Set 15 | tarauaca
# Processing Record 33 of Set 15 | kaohsiung
# Processing Record 34 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 15 | markala
# Processing Record 36 of Set 15 | porkhov
# Processing Record 37 of Set 15 | stornoway
# Processing Record 38 of Set 15 | dalby
# Processing Record 39 of Set 15 | voyvozh
# Processing Record 40 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 15 | zychlin
# Processing Record 42 of Set 15 | yerbogachen
# Processing Record 43 of Set 15 | hamada
# Processing Record 44 of Set 15 | thinadhoo
# Processing Record 45 of Set 15 | auki
# Processing Record 46 of Set 15 | moshupa
# Processing Record 47 of Set 15 | kaura namoda
# Processing Record 48 of Set 15 | san carlos de bariloche
# Processing Record 49 of Set 15 | springdale
# Processing Record 50 of Set 15 | bahia de caraquez
# Processing Record 1 of Set 16 | upington
# Processing Record 2 of Set 16 | kracheh
# City not found. Skipping...
# Processing Record 3 of Set 16 | guiren
# Processing Record 4 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 16 | luganville
# Processing Record 6 of Set 16 | san carlos
# Processing Record 7 of Set 16 | dolgorukovo
# Processing Record 8 of Set 16 | seoul
# Processing Record 9 of Set 16 | ranong
# Processing Record 10 of Set 16 | kierspe
# Processing Record 11 of Set 16 | mayo
# Processing Record 12 of Set 16 | aybak
# City not found. Skipping...
# Processing Record 13 of Set 16 | naco
# Processing Record 14 of Set 16 | galesong
# Processing Record 15 of Set 16 | juruti
# Processing Record 16 of Set 16 | saint-medard-en-jalles
# Processing Record 17 of Set 16 | praia
# Processing Record 18 of Set 16 | chunoyar
# Processing Record 19 of Set 16 | udachnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Add city data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Colombia  10.9878  -74.9547     80.69        84         100
# 1           Torbay  47.6666  -52.7314     41.88        84         100
# 2           Atuona  -9.8000 -139.0333     77.90        69           5
# 3             Aksu  41.1231   80.2644     82.87        17          83
# 4           Hobart -42.8794  147.3294     48.25        83          40
#
#    Wind Speed Country Current Description
# 0        7.83      CO     overcast clouds
# 1        8.05      CA     overcast clouds
# 2       16.04      PF           clear sky
# 3       10.58      CN       broken clouds
# 4        8.05      AU    scattered clouds

# %%
# Reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Puerto Colombia      CO  10.9878  -74.9547     80.69        84
# 1                    Torbay      CA  47.6666  -52.7314     41.88        84
# 2                    Atuona      PF  -9.8000 -139.0333     77.90        69
# 3                      Aksu      CN  41.1231   80.2644     82.87        17
# 4                    Hobart      AU -42.8794  147.3294     48.25        83
# ..                      ...     ...      ...       ...       ...       ...
# 701                  Juruti      BR  -2.1522  -56.0922     79.72        85
# 702  Saint-Medard-En-Jalles      FR  44.8969   -0.7214     80.31        57
# 703                   Praia      CV  14.9215  -23.5087     86.54        37
# 704                Chunoyar      RU  57.4467   97.3217     64.44        72
# 705                Udachnyy      RU  66.4167  112.4000     35.28       100
#
#      Cloudiness  Wind Speed Current Description
# 0           100        7.83     overcast clouds
# 1           100        8.05     overcast clouds
# 2             5       16.04           clear sky
# 3            83       10.58       broken clouds
# 4            40        8.05    scattered clouds
# ..          ...         ...                 ...
# 701          99        5.08     overcast clouds
# 702          40        6.91    scattered clouds
# 703           0       21.85           clear sky
# 704          92        8.23     overcast clouds
# 705         100        3.85     overcast clouds
#
# [706 rows x 9 columns]

# %%
# Export dataframe
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
